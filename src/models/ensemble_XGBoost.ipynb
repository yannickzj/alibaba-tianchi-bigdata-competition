# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import datetime as dt

# %%
# loading original data
shopInfoFile = '../dataset/shop_info.txt'

shopInfo = pd.read_table(shopInfoFile, sep = ',', header = None)
shopInfo.columns = ['shopID', 'city', 'locationID', 'perPay', 'score', 'commentCnt', 'shopLevel', 'cate1', 'cate2', 'cate3']

# %%
# define evaluation function
def evaluation(preds, dtrain):
    labels = dtrain.get_label()
    num = len(labels)
    return 'loss', abs((labels - preds)/(labels + preds)).sum()/num

# %%
#load training and testing data
payTH = pd.read_csv('../preprocess/payTH_parallel.txt', sep=" ", header = None)
trainFile = '../preprocess/trainValidFeatures_ensemble.csv'
testFile = '../preprocess/validFeatures_ensemble.csv'
trainData = pd.read_csv(trainFile, header = None)
testData = pd.read_csv(testFile, header = None)

periods = [7, 14, 28, 56, 112]
stats = ['mean', 'std', 'skew', 'kurtosis']
recentDataColumns = []
for period in periods:
    for stat in stats:
        column  = 'last' + str(period) + 'days_' + stat
        recentDataColumns.append(column)

periods = [7, 14, 28]
stats = ['meanView', 'stdView', 'skewView', 'kurtosisView']
recentDataViewColumns = []
for period in periods:
    for stat in stats:
        column = 'last' + str(period) + 'days_' + stat
        recentDataViewColumns.append(column)            
        
periods = [7, 14, 28, 56, 112]
trends = ['copy', 'ridge']
currentTrendcolumns = []
for period in periods:
    for trend in trends:
        column = 'last' + str(period) + 'days_' + trend
        currentTrendcolumns.append(column)
        
primaryKey = ['shopID', 'year', 'month', 'day']
columnDic = {
    'basicInfo':['city', 'perPay', 'score', 'commentCnt', 'shopLevel', 'category'],
    'recentData':recentDataColumns,
    'recentDataView':recentDataViewColumns,
    'currentTrend':currentTrendcolumns,
    'temporalInfo':['dayOfWeek', 'holiday', 'numHolidayLast', 'numHolidayCur', 'numHolidayNext'],
    'weather':['maxTemp', 'minTemp', 'weather', 'pm']
}

ensembleCol = ['shopID', 'year', 'month', 'day']
orderCol = ['basicInfo', 'recentData', 'temporalInfo', 'currentTrend', 'weather', 'recentDataView']
for col in orderCol:
    ensembleCol = ensembleCol + columnDic[col]
    
trainData.columns = ensembleCol
testData.columns = ensembleCol

# %% [markdown]
# # ensemble model for validation

# %%
startDateTrain = dt.date(2016, 9, 20)
endDateTrain = dt.date(2016, 10, 17)
startDateTest = dt.date(2016, 10, 18)
endDateTest = dt.date(2016, 10, 31)
startDate = dt.date(2015, 7, 1)
endDate = dt.date(2016, 10, 31)

startTrain = (startDateTrain - startDate).days
endTrain = (endDateTrain - startDate).days
startValid = (startDateTest - startDate).days
endValid = (endDateTest - startDate).days

# %%
featureNum = 25   # 1/3 features
totalNum = len(ensembleCol)

randomNum = 500   # 500 random models

trainLabel = payTH[np.arange(startTrain, endTrain + 1)].values.reshape(1, -1)[0]
validLabel = payTH[np.arange(startValid, endValid + 1)].values.reshape(1, -1)[0]

params = {
    'objective':'reg:linear',
    'max_depth':5,
    'silent':1,
    'eta':0.02,
    'subsample':0.9,
    'colsample_bytree':0.7,
}
num_rounds = 1000

randomPreds = []
randomFeatures = []

for i in range(randomNum):
    print("calculating model {}".format(i + 1))
    indexFeature = np.random.permutation(totalNum)[:featureNum]
    selectCol = [ensembleCol[k] for k in indexFeature]
    randomFeatures.append(selectCol)
    
    dtrain = xgb.DMatrix(data = trainData[selectCol].values, label = trainLabel, missing=np.nan)
    dval = xgb.DMatrix(data = testData[selectCol].values, missing=np.nan)

    bst = xgb.train(params, dtrain, num_rounds)
    pred = bst.predict(dval)
    randomPreds.append(abs(pred.astype(np.int32)))

print("storing the results...")
randomPredsDF = pd.DataFrame(randomPreds)
randomFeaturesDF = pd.DataFrame(randomFeatures)
randomPredsDF.to_csv('../combination/randomPreds.csv', header = False, index = False)
randomFeaturesDF.to_csv('../combination/randomFeatures.csv', header = False, index = False)

combination = []

recordNum = len(validLabel)
randomPreds = np.array(randomPreds)

minCombination = []
minEvaluation = 1.0

num = len(randomFeatures)

for i in range(num):
    combination.append([])
    if i % 50 == 0:
        print(i)
    for j in range(num):
        pair = (randomPreds[i] + randomPreds[j])/2
        evaluation = abs((validLabel - pair)/(validLabel + pair)).sum()/recordNum
        combination[i].append(evaluation)
        if evaluation < minEvaluation:
            minEvaluation = evaluation
            minCombination = [i, j]
        
combinationDF = pd.DataFrame(combination)
combinationDF.to_csv('../combination/combination.csv', header = False, index = False)
combinationDF
# Out:
# calculating model 1
# calculating model 2
# calculating model 3
# calculating model 4
# calculating model 5
# calculating model 6
# calculating model 7
# calculating model 8
# calculating model 9
# calculating model 10
# calculating model 11
# calculating model 12
# calculating model 13
# calculating model 14
# calculating model 15
# calculating model 16
# calculating model 17
# calculating model 18
# calculating model 19
# calculating model 20
# calculating model 21
# calculating model 22
# calculating model 23
# calculating model 24
# calculating model 25
# calculating model 26
# calculating model 27
# calculating model 28
# calculating model 29
# calculating model 30
# calculating model 31
# calculating model 32
# calculating model 33
# calculating model 34
# calculating model 35
# calculating model 36
# calculating model 37
# calculating model 38
# calculating model 39
# calculating model 40
# calculating model 41
# calculating model 42
# calculating model 43
# calculating model 44
# calculating model 45
# calculating model 46
# calculating model 47
# calculating model 48
# calculating model 49
# calculating model 50
# calculating model 51
# calculating model 52
# calculating model 53
# calculating model 54
# calculating model 55
# calculating model 56
# calculating model 57
# calculating model 58
# calculating model 59
# calculating model 60
# calculating model 61
# calculating model 62
# calculating model 63
# calculating model 64
# calculating model 65
# calculating model 66
# calculating model 67
# calculating model 68
# calculating model 69
# calculating model 70
# calculating model 71
# calculating model 72
# calculating model 73
# calculating model 74
# calculating model 75
# calculating model 76
# calculating model 77
# calculating model 78
# calculating model 79
# calculating model 80
# calculating model 81
# calculating model 82
# calculating model 83
# calculating model 84
# calculating model 85
# calculating model 86
# calculating model 87
# calculating model 88
# calculating model 89
# calculating model 90
# calculating model 91
# calculating model 92
# calculating model 93
# calculating model 94
# calculating model 95
# calculating model 96
# calculating model 97
# calculating model 98
# calculating model 99
# calculating model 100
# calculating model 101
# calculating model 102
# calculating model 103
# calculating model 104
# calculating model 105
# calculating model 106
# calculating model 107
# calculating model 108
# calculating model 109
# calculating model 110
# calculating model 111
# calculating model 112
# calculating model 113
# calculating model 114
# calculating model 115
# calculating model 116
# calculating model 117
# calculating model 118
# calculating model 119
# calculating model 120
# calculating model 121
# calculating model 122
# calculating model 123
# calculating model 124
# calculating model 125
# calculating model 126
# calculating model 127
# calculating model 128
# calculating model 129
# calculating model 130
# calculating model 131
# calculating model 132
# calculating model 133
# calculating model 134
# calculating model 135
# calculating model 136
# calculating model 137
# calculating model 138
# calculating model 139
# calculating model 140
# calculating model 141
# calculating model 142
# calculating model 143
# calculating model 144
# calculating model 145
# calculating model 146
# calculating model 147
# calculating model 148
# calculating model 149
# calculating model 150
# calculating model 151
# calculating model 152
# calculating model 153
# calculating model 154
# calculating model 155
# calculating model 156
# calculating model 157
# calculating model 158
# calculating model 159
# calculating model 160
# calculating model 161
# calculating model 162
# calculating model 163
# calculating model 164
# calculating model 165
# calculating model 166
# calculating model 167
# calculating model 168
# calculating model 169
# calculating model 170
# calculating model 171
# calculating model 172
# calculating model 173
# calculating model 174
# calculating model 175
# calculating model 176
# calculating model 177
# calculating model 178
# calculating model 179
# calculating model 180
# calculating model 181
# calculating model 182
# calculating model 183
# calculating model 184
# calculating model 185
# calculating model 186
# calculating model 187
# calculating model 188
# calculating model 189
# calculating model 190
# calculating model 191
# calculating model 192
# calculating model 193
# calculating model 194
# calculating model 195
# calculating model 196
# calculating model 197
# calculating model 198
# calculating model 199
# calculating model 200
# calculating model 201
# calculating model 202
# calculating model 203
# calculating model 204
# calculating model 205
# calculating model 206
# calculating model 207
# calculating model 208
# calculating model 209
# calculating model 210
# calculating model 211
# calculating model 212
# calculating model 213
# calculating model 214
# calculating model 215
# calculating model 216
# calculating model 217
# calculating model 218
# calculating model 219
# calculating model 220
# calculating model 221
# calculating model 222
# calculating model 223
# calculating model 224
# calculating model 225
# calculating model 226
# calculating model 227
# calculating model 228
# calculating model 229
# calculating model 230
# calculating model 231
# calculating model 232
# calculating model 233
# calculating model 234
# calculating model 235
# calculating model 236
# calculating model 237
# calculating model 238
# calculating model 239
# calculating model 240
# calculating model 241
# calculating model 242
# calculating model 243
# calculating model 244
# calculating model 245
# calculating model 246
# calculating model 247
# calculating model 248
# calculating model 249
# calculating model 250
# calculating model 251
# calculating model 252
# calculating model 253
# calculating model 254
# calculating model 255
# calculating model 256
# calculating model 257
# calculating model 258
# calculating model 259
# calculating model 260
# calculating model 261
# calculating model 262
# calculating model 263
# calculating model 264
# calculating model 265
# calculating model 266
# calculating model 267
# calculating model 268
# calculating model 269
# calculating model 270
# calculating model 271
# calculating model 272
# calculating model 273
# calculating model 274
# calculating model 275
# calculating model 276
# calculating model 277
# calculating model 278
# calculating model 279
# calculating model 280
# calculating model 281
# calculating model 282
# calculating model 283
# calculating model 284
# calculating model 285
# calculating model 286
# calculating model 287
# calculating model 288
# calculating model 289
# calculating model 290
# calculating model 291
# calculating model 292
# calculating model 293
# calculating model 294
# calculating model 295
# calculating model 296
# calculating model 297
# calculating model 298
# calculating model 299
# calculating model 300
# calculating model 301
# calculating model 302
# calculating model 303
# calculating model 304
# calculating model 305
# calculating model 306
# calculating model 307
# calculating model 308
# calculating model 309
# calculating model 310
# calculating model 311
# calculating model 312
# calculating model 313
# calculating model 314
# calculating model 315
# calculating model 316
# calculating model 317
# calculating model 318
# calculating model 319
# calculating model 320
# calculating model 321
# calculating model 322
# calculating model 323
# calculating model 324
# calculating model 325
# calculating model 326
# calculating model 327
# calculating model 328
# calculating model 329
# calculating model 330
# calculating model 331
# calculating model 332
# calculating model 333
# calculating model 334
# calculating model 335
# calculating model 336
# calculating model 337
# calculating model 338
# calculating model 339
# calculating model 340
# calculating model 341
# calculating model 342
# calculating model 343
# calculating model 344
# calculating model 345
# calculating model 346
# calculating model 347
# calculating model 348
# calculating model 349
# calculating model 350
# calculating model 351
# calculating model 352
# calculating model 353
# calculating model 354
# calculating model 355
# calculating model 356
# calculating model 357
# calculating model 358
# calculating model 359
# calculating model 360
# calculating model 361
# calculating model 362
# calculating model 363
# calculating model 364
# calculating model 365
# calculating model 366
# calculating model 367
# calculating model 368
# calculating model 369
# calculating model 370
# calculating model 371
# calculating model 372
# calculating model 373
# calculating model 374
# calculating model 375
# calculating model 376
# calculating model 377
# calculating model 378
# calculating model 379
# calculating model 380
# calculating model 381
# calculating model 382
# calculating model 383
# calculating model 384
# calculating model 385
# calculating model 386
# calculating model 387
# calculating model 388
# calculating model 389
# calculating model 390
# calculating model 391
# calculating model 392
# calculating model 393
# calculating model 394
# calculating model 395
# calculating model 396
# calculating model 397
# calculating model 398
# calculating model 399
# calculating model 400
# calculating model 401
# calculating model 402
# calculating model 403
# calculating model 404
# calculating model 405
# calculating model 406
# calculating model 407
# calculating model 408
# calculating model 409
# calculating model 410
# calculating model 411
# calculating model 412
# calculating model 413
# calculating model 414
# calculating model 415
# calculating model 416
# calculating model 417
# calculating model 418
# calculating model 419
# calculating model 420
# calculating model 421
# calculating model 422
# calculating model 423
# calculating model 424
# calculating model 425
# calculating model 426
# calculating model 427
# calculating model 428
# calculating model 429
# calculating model 430
# calculating model 431
# calculating model 432
# calculating model 433
# calculating model 434
# calculating model 435
# calculating model 436
# calculating model 437
# calculating model 438
# calculating model 439
# calculating model 440
# calculating model 441
# calculating model 442
# calculating model 443
# calculating model 444
# calculating model 445
# calculating model 446
# calculating model 447
# calculating model 448
# calculating model 449
# calculating model 450
# calculating model 451
# calculating model 452
# calculating model 453
# calculating model 454
# calculating model 455
# calculating model 456
# calculating model 457
# calculating model 458
# calculating model 459
# calculating model 460
# calculating model 461
# calculating model 462
# calculating model 463
# calculating model 464
# calculating model 465
# Out:
# 0.09579756084276006

# %%
randomFeatures[minCombination[0]]
# Out:
# ['last28days_meanView',
#  'month',
#  'dayOfWeek',
#  'numHolidayNext',
#  'last7days_std',
#  'last28days_stdView',
#  'category',
#  'last28days_kurtosisView',
#  'last7days_skewView',
#  'last28days_skewView',
#  'last28days_kurtosis',
#  'last14days_stdView',
#  'last56days_ridge',
#  'day',
#  'last112days_ridge',
#  'last14days_ridge',
#  'pm',
#  'last14days_mean',
#  'last28days_std',
#  'last7days_copy',
#  'holiday',
#  'last112days_skew',
#  'perPay',
#  'last112days_copy',
#  'last28days_skew']

# %%
randomFeatures[minCombination[1]]
# Out:
# ['weather',
#  'numHolidayLast',
#  'last7days_skew',
#  'maxTemp',
#  'last28days_stdView',
#  'last56days_kurtosis',
#  'category',
#  'last7days_copy',
#  'last14days_skew',
#  'year',
#  'shopLevel',
#  'last7days_kurtosisView',
#  'last28days_kurtosisView',
#  'month',
#  'last7days_std',
#  'last14days_std',
#  'last28days_std',
#  'commentCnt',
#  'dayOfWeek',
#  'holiday',
#  'score',
#  'last56days_ridge',
#  'last56days_copy',
#  'last7days_ridge',
#  'numHolidayCur']

# %% [markdown]
# # ensemble model for final submission

# %%
trainPredFile = '../preprocess/trainTestFeatures_ensemble.csv'
trainPredData = pd.read_csv(trainPredFile, header = None)
testPredFile = '../preprocess/testFeatures_ensemble.csv'
testPredData = pd.read_csv(testPredFile, header = None)
trainPredData.columns = ensembleCol
testPredData.columns = ensembleCol

startDateTrain = dt.date(2016, 10, 4)
endDateTrain = dt.date(2016, 10, 31)
startDateTest = dt.date(2016, 11, 1)
endDateTest = dt.date(2016, 11, 14)
startDate = dt.date(2015, 7, 1)
endDate = dt.date(2016, 10, 31)

startTrain = (startDateTrain - startDate).days
endTrain = (endDateTrain - startDate).days
startValid = (startDateTest - startDate).days
endValid = (endDateTest - startDate).days

params = {
    'objective':'reg:linear',
    'max_depth':5,
    'silent':1,
    'eta':0.02,
    'subsample':0.9,
    'colsample_bytree':0.7,
}
num_rounds = 1000
trainPredLabel = payTH[np.arange(startTrain, endTrain + 1)].values.reshape(1, -1)[0]

# %%
minPairPreds = []

for i in range(len(minCombination)):
    print("calculating minCombination model {}".format(i + 1))
    selectCol = randomFeatures[minCombination[i]]
    
    dtrain = xgb.DMatrix(data = trainPredData[selectCol].values, label = trainPredLabel, missing=np.nan)
    dtest = xgb.DMatrix(data = testPredData[selectCol].values, missing=np.nan)
    
    bst = xgb.train(params, dtrain, num_rounds)
    pred = bst.predict(dtest)
    minPairPreds.append(abs(pred.astype(np.int32)))

minPred = (minPairPreds[0] + minPairPreds[1])/2
# Out:
# calculating minCombination model 1
# calculating minCombination model 2

# %%
# save submission file
submit = minPred.reshape(-1, 14).astype(np.int32)
submitDF = pd.DataFrame(submit, index = (np.arange(2000) + 1))
submitDF.to_csv('../prediction/ensembleXGBoost.csv', header = False, index = True, date_format = 'int32')
